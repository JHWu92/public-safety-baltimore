# %%
import geopandas as gpd

# %%
gpdf = gpd.read_file("Recreation_20Center/recreation_center.shp")

# %%
gpdf.shape
# Out:
# (60, 24)

# %%
gpdf.head().T
# Out:
#                                                       0  \
# ADDRESS                                     3560 3rd St
# AMENITIES     Adjacent park: plgd, basketball, baseball
# BLDG_DESC                              1 story concrete
# BLDG_SQFT                                          6185
# BUILT_DT                                           1966
# CNCL_DIST                                            10
# COMMENT                                      Former PAL
# CONTACT                                   Kathy Furtado
# NAME                                  Brooklyn O'Malley
# NEIGHBRHD                                      Brooklyn
# Notes
# OBJECTID                                              1
# PARK_DIST                                       Carroll
# PHONE                                      410-396-1832
# POLC_DIST                                             S
# REC_DIST                                              S
# RENOVATED
# ...
